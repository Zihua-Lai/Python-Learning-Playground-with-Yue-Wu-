# %% [markdown]
# **Exercise 1: Basic tuple operations**

# %%
# create a tuple with 3 elements and print this tuple
tuple = ("I love you", 24)
print("The thing I created is:",tuple)
# Out:
# The thing I created is: ('I love you', 24)

# %% [markdown]
# **Exercise 2: Accessing tuple elements**

# %%
# write a function to print the second element in a tuple
touple_1 = (1,2,3,4)
second_element = touple_1[1]
print(second_element)
# Out:
# 2

# %% [markdown]
# **Exercise 3: Tuple immutability**

# %%
# Try to change the element in a tuple, and observe what will happen
tuple_1 = (1,2,3,4,5)
tuple_1[3]= 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1632831311.py in <cell line: 0>()
#       1 # Try to change the element in a tuple, and observe what will happen
#       2 tuple_1 = (1,2,3,4,5)
# ----> 3 tuple_1[3]= 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
# here we introduce a code for dealing with the abnormal value
tuple_1 = (2,3,4,5,6)
try:
  tuple_1[0] = 3
except TypeError as e:
  print("error:", e)
# Out:
# error: 'tuple' object does not support item assignment

# %% [markdown]
# **Exercise 4: Slicing and splitting tuples**

# %%
# Given 2 tuples, merge them , get a new tuple, which indludes all of the elements in original tuple
tuple_1 = (1,2,3,4,5)
tuple_2 = (6, 7, 8, 9, 0)
print(tuple_1 + tuple_2)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9, 0)

# %% [markdown]
# **Exercise 5: Tuple-list conversion**

# %%
# given a tuple , change it to list, and add an element in the list ,then change the list to tuple
tuple_1 = (1,2,3,3)
list_1 = list(tuple_1)
list_1.append(4)
tuple_2 = tuple(list_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3648041751.py in <cell line: 0>()
#       3 list_1 = list(tuple_1)
#       4 list_1.append(4)
# ----> 5 tuple_2 = tuple(list_1)
#
# TypeError: 'tuple' object is not callable
